# %% [markdown]
# # **Data Loading**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('Indian_Dataset.csv')
df
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# 3            Waste to Wonder Park    Theme Park               2019
# 4                   Jantar Mantar   Observatory               1724
# ..                            ...           ...                ...
# 320                    Akshardham        Temple               1992
# 321                     Agra Fort          Fort               1565
# 322  Madhya Pradesh Tribal Museum        Museum               2013
# 323                   City Palace        Palace               1727
# 324            Albert Hall Museum        Museum               1887
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR  \
# 0                            0.5                   4.6                    0
# 1                            2.0                   4.5                   30
# 2                            5.0                   4.6                   60
# 3                            2.0                   4.1                   50
# 4                            2.0                   4.2                   15
# ..                           ...                   ...                  ...
# 320                          3.0                   4.6                    0
# 321                          2.0                   4.5                   40
# 322                          2.0                   4.7                   10
# 323                          2.0                   4.4                  200
# 324                          2.0                   4.5                  200
#
#     Airport with 50km Radius Weekly Off   Significance DSLR Allowed  \
# 0                        Yes        NaN     Historical          Yes
# 1                        Yes        NaN     Historical          Yes
# 2                        Yes        NaN      Religious           No
# 3                        Yes     Monday  Environmental          Yes
# 4                        Yes        NaN     Scientific          Yes
# ..                       ...        ...            ...          ...
# 320                      Yes     Monday      Religious           No
# 321                      Yes        NaN     Historical          Yes
# 322                      Yes     Monday       Cultural          Yes
# 323                      Yes        NaN     Historical          Yes
# 324                      Yes        NaN     Historical          Yes
#
#      Number of google review in lakhs Best Time to visit
# 0                                2.60            Evening
# 1                                0.40          Afternoon
# 2                                0.40          Afternoon
# 3                                0.27            Evening
# 4                                0.31            Morning
# ..                                ...                ...
# 320                              0.18                All
# 321                              1.30          Afternoon
# 322                              0.15                All
# 323                              0.51            Morning
# 324                              0.63                All
#
# [325 rows x 16 columns]

# %%
df['Weekly Off'].fillna("No", inplace=True)
# Out:
# <ipython-input-3-447c5a159a23>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weekly Off'].fillna("No", inplace=True)

# %%
df
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# 3            Waste to Wonder Park    Theme Park               2019
# 4                   Jantar Mantar   Observatory               1724
# ..                            ...           ...                ...
# 320                    Akshardham        Temple               1992
# 321                     Agra Fort          Fort               1565
# 322  Madhya Pradesh Tribal Museum        Museum               2013
# 323                   City Palace        Palace               1727
# 324            Albert Hall Museum        Museum               1887
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR  \
# 0                            0.5                   4.6                    0
# 1                            2.0                   4.5                   30
# 2                            5.0                   4.6                   60
# 3                            2.0                   4.1                   50
# 4                            2.0                   4.2                   15
# ..                           ...                   ...                  ...
# 320                          3.0                   4.6                    0
# 321                          2.0                   4.5                   40
# 322                          2.0                   4.7                   10
# 323                          2.0                   4.4                  200
# 324                          2.0                   4.5                  200
#
#     Airport with 50km Radius Weekly Off   Significance DSLR Allowed  \
# 0                        Yes         No     Historical          Yes
# 1                        Yes         No     Historical          Yes
# 2                        Yes         No      Religious           No
# 3                        Yes     Monday  Environmental          Yes
# 4                        Yes         No     Scientific          Yes
# ..                       ...        ...            ...          ...
# 320                      Yes     Monday      Religious           No
# 321                      Yes         No     Historical          Yes
# 322                      Yes     Monday       Cultural          Yes
# 323                      Yes         No     Historical          Yes
# 324                      Yes         No     Historical          Yes
#
#      Number of google review in lakhs Best Time to visit
# 0                                2.60            Evening
# 1                                0.40          Afternoon
# 2                                0.40          Afternoon
# 3                                0.27            Evening
# 4                                0.31            Morning
# ..                                ...                ...
# 320                              0.18                All
# 321                              1.30          Afternoon
# 322                              0.15                All
# 323                              0.51            Morning
# 324                              0.63                All
#
# [325 rows x 16 columns]

# %% [markdown]
# # **Content Based Filtering**

# %%
df['features'] =df['Name'] + ' ' + df['Zone'] + ' ' + df['State'] + ' ' + df['City'] + " " + df['Type'] + " " + df['Establishment Year'] + " " + df['Weekly Off'] + " " + df['Significance'] + " " + df['DSLR Allowed'] + " " + df['Best Time to visit']

vectorizer = TfidfVectorizer(stop_words='english')

destination_features = vectorizer.fit_transform(df['features'])

cosine_sim = cosine_similarity(destination_features, destination_features)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Zone', 'State', 'City', 'Name', 'Type',
#        'Establishment Year', 'time needed to visit in hrs',
#        'Google review rating', 'Entrance Fee in INR',
#        'Airport with 50km Radius', 'Weekly Off', 'Significance',
#        'DSLR Allowed', 'Number of google review in lakhs',
#        'Best Time to visit', 'features'],
#       dtype='object')

# %%
from IPython.display import display  # For displaying tables in Google Colab

def recommend_similar_places(place_name, df, cosine_sim, top_n=10):
    try:
        idx = df[df['Name'].str.lower() == place_name.lower()].index[0]
        sim_scores = list(enumerate(cosine_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        top_destinations_idx = [i[0] for i in sim_scores[1:top_n+1]]

        recommendations = df.iloc[top_destinations_idx][[
            'Name', 'State', 'City', 'Type', 'Establishment Year', 'time needed to visit in hrs', 'Google review rating', 'Entrance Fee in INR', 'Airport with 50km Radius', 'Weekly Off', 'Significance', 'DSLR Allowed', 'Best Time to visit', 'features'
        ]]

        recommendations.reset_index(drop=True, inplace=True)  # Remove index
        display(recommendations)  # Display in table format

    except IndexError:
        print("Place not found! Please enter a valid place name.")

# Example: Get 10 recommendations similar to "India Gate"
recommend_similar_places('India Gate', df, cosine_sim, top_n=10)
# Out:
#                     Name           State           City          Type  \
# 0           War Memorial  Andhra Pradesh  Visakhapatnam  War Memorial
# 1      Dras War Memorial          Ladakh           Dras  War Memorial
# 2           Lotus Temple           Delhi          Delhi        Temple
# 3    Kargil War Memorial          Ladakh         Kargil  War Memorial
# 4               Red Fort           Delhi          Delhi          Fort
# 5      Akshardham Temple           Delhi          Delhi        Temple
# 6            Qutub Minar           Delhi          Delhi      Monument
# 7           Lodhi Garden           Delhi          Delhi          Park
# 8            Jama Masjid           Delhi      New Delhi        Mosque
# 9  Garden of Five Senses           Delhi          Delhi          Park
#
#   Establishment Year  time needed to visit in hrs  Google review rating  \
# 0            Unknown                          1.0                   4.6
# 1            Unknown                          1.0                   4.8
# 2               1986                          1.0                   4.5
# 3                 24                          1.0                   4.8
# 4               1648                          2.0                   4.5
# 5               2005                          5.0                   4.6
# 6               1192                          1.0                   4.5
# 7               1500                          1.0                   4.5
# 8               1656                          1.0                   4.5
# 9               2003                          2.0                   4.1
#
#    Entrance Fee in INR Airport with 50km Radius Weekly Off Significance  \
# 0                    0                      Yes         No   Historical
# 1                    0                       No         No   Historical
# 2                    0                      Yes     Monday    Religious
# 3                    0                       No         No   Historical
# 4                   35                      Yes         No   Historical
# 5                   60                      Yes         No    Religious
# 6                   35                      Yes         No   Historical
# 7                    0                      Yes         No    Botanical
# 8                    0                      Yes         No   Historical
# 9                   35                      Yes         No    Botanical
#
#   DSLR Allowed Best Time to visit  \
# 0          Yes                All
# 1          Yes                All
# 2          Yes            Evening
# 3          Yes                All
# 4          Yes          Afternoon
# 5           No          Afternoon
# 6          Yes          Afternoon
# 7          Yes                All
# 8          Yes                All
# 9          Yes            Morning
#
#                                             features
# 0  War Memorial Southern Andhra Pradesh Visakhapa...
# 1  Dras War Memorial Northern Ladakh Dras War Mem...
# 2  Lotus Temple Northern Delhi Delhi Temple 1986 ...
# 3  Kargil War Memorial Northern Ladakh Kargil War...
# 4  Red Fort Northern Delhi Delhi Fort 1648 No His...
# 5  Akshardham Temple Northern Delhi Delhi Temple ...
# 6  Qutub Minar Northern Delhi Delhi Monument 1192...
# 7  Lodhi Garden Northern Delhi Delhi Park 1500 No...
# 8  Jama Masjid Northern Delhi New Delhi Mosque 16...
# 9  Garden of Five Senses Northern Delhi Delhi Par...

# %% [markdown]
# # **Rule Based Filtering**

# %%
from IPython.display import display

def filter_places(user_input, df):

    filtered_df = df.copy()

    # Apply filters based on user input
    if 'Zone' in user_input:
        filtered_df = filtered_df[filtered_df['Zone'] == user_input['Zone']]

    if 'State' in user_input:
        filtered_df = filtered_df[filtered_df['State'] == user_input['State']]

    if 'City' in user_input:
        filtered_df = filtered_df[filtered_df['City'] == user_input['City']]

    if 'Type' in user_input:
        filtered_df = filtered_df[filtered_df['Type'] == user_input['Type']]

    if 'time needed to visit in hrs' in user_input:
        min_time = float(user_input['time needed to visit in hrs'])
        filtered_df = filtered_df[filtered_df['time needed to visit in hrs'] >= min_time]

    if 'Google review rating' in user_input:
        min_rating = float(user_input['Google review rating'])
        filtered_df = filtered_df[filtered_df['Google review rating'] >= min_rating]

    if 'Entrance Fee in INR' in user_input:
        max_fee = int(user_input['Entrance Fee in INR'])
        filtered_df = filtered_df[filtered_df['Entrance Fee in INR'] <= max_fee]

    if 'DSLR Allowed' in user_input:
        filtered_df = filtered_df[filtered_df['DSLR Allowed'].str.lower() == user_input['DSLR Allowed'].lower()]

    if 'Best Time to visit' in user_input:
        filtered_df = filtered_df[filtered_df['Best Time to visit'].str.lower() == user_input['Best Time to visit'].lower()]

    # If no filters provided, sort by rating * number of reviews
    if not user_input:
        filtered_df['popularity_score'] = filtered_df['Google review rating'] * filtered_df['Number of google review in lakhs']
        filtered_df = filtered_df.sort_values(by='popularity_score', ascending=False)

    # Return final filtered results
    return filtered_df[['Name', 'Zone', 'State', 'City', 'Type', 'Google review rating', 'Entrance Fee in INR', 'DSLR Allowed', 'Best Time to visit']]

# Example User Input
user_input = {
    'State': 'Delhi',
    'Google review rating': '4',
    'Best Time to visit': 'morning'
}

# Get recommendations
recommended_places = filter_places(user_input, df)
recommended_places.reset_index(drop=True, inplace=True)
display(recommended_places)
# Out:
#                     Name      Zone  State       City         Type  \
# 0          Jantar Mantar  Northern  Delhi      Delhi  Observatory
# 1  Garden of Five Senses  Northern  Delhi      Delhi         Park
# 2            Rail Museum  Northern  Delhi  New Delhi       Museum
#
#    Google review rating  Entrance Fee in INR DSLR Allowed Best Time to visit
# 0                   4.2                   15          Yes            Morning
# 1                   4.1                   35          Yes            Morning
# 2                   4.4                   50          Yes            Morning
